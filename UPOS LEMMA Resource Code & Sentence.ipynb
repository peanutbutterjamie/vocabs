# %%
import pandas as pd
import re
import pickle
import numpy as np
from IPython.display import clear_output
from tqdm import tqdm
from LemmaCount import rscode_sentence, srcode_sentence
pd.set_option("display.max_columns", None)
pd.set_option('max_colwidth', None)

# %% [markdown]
# # Run the code and enter LEMMA:UPOS
#
# ![image-2.png](attachment:image-2.png)
#
# ### rscode_sentence( )
# - LEMMA : upper case ->  NOUN, VERB, ADJ, ADV
# - UPOS : lower case
#
#     - example
#         * NOUN:product
#         * VERB:increase
#         * ADJ:important
#         * ADV:finally

# %%
rscode_sentence()
# Out:
# |enter the UPOS:LEMMA -> VERB:release
# |If you want to see only sentences : Enter 1
# |If you want to see resource codes only : Enter 2
# |If you want to see both sentences and resource codes : Enter 33
#
#
# < VERB:release >  appeared in 8 resources.
# ALP-Z5, ANF-5, ANF-6, ESC-4, ESC-5, ESC-6
# PTF4.2, ERK3
#
# < VERB:release >  appeared in 28 sentences.
# <style type="text/css">
# #T_a9d2d_row0_col0, #T_a9d2d_row0_col1, #T_a9d2d_row1_col0, #T_a9d2d_row1_col1, #T_a9d2d_row2_col0, #T_a9d2d_row2_col1, #T_a9d2d_row3_col0, #T_a9d2d_row3_col1, #T_a9d2d_row4_col0, #T_a9d2d_row4_col1, #T_a9d2d_row5_col0, #T_a9d2d_row5_col1, #T_a9d2d_row6_col0, #T_a9d2d_row6_col1, #T_a9d2d_row7_col0, #T_a9d2d_row7_col1, #T_a9d2d_row8_col0, #T_a9d2d_row8_col1, #T_a9d2d_row9_col0, #T_a9d2d_row9_col1, #T_a9d2d_row10_col0, #T_a9d2d_row10_col1, #T_a9d2d_row11_col0, #T_a9d2d_row11_col1, #T_a9d2d_row12_col0, #T_a9d2d_row12_col1, #T_a9d2d_row13_col0, #T_a9d2d_row13_col1, #T_a9d2d_row14_col0, #T_a9d2d_row14_col1, #T_a9d2d_row15_col0, #T_a9d2d_row15_col1, #T_a9d2d_row16_col0, #T_a9d2d_row16_col1, #T_a9d2d_row17_col0, #T_a9d2d_row17_col1, #T_a9d2d_row18_col0, #T_a9d2d_row18_col1, #T_a9d2d_row19_col0, #T_a9d2d_row19_col1, #T_a9d2d_row20_col0, #T_a9d2d_row20_col1, #T_a9d2d_row21_col0, #T_a9d2d_row21_col1, #T_a9d2d_row22_col0, #T_a9d2d_row22_col1, #T_a9d2d_row23_col0, #T_a9d2d_row23_col1, #T_a9d2d_row24_col0, #T_a9d2d_row24_col1, #T_a9d2d_row25_col0, #T_a9d2d_row25_col1, #T_a9d2d_row26_col0, #T_a9d2d_row26_col1, #T_a9d2d_row27_col0, #T_a9d2d_row27_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_a9d2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9d2d_level0_col0" class="col_heading level0 col0" >RS Code</th>
#       <th id="T_a9d2d_level0_col1" class="col_heading level0 col1" >Sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9d2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9d2d_row0_col0" class="data row0 col0" >ALP-Z5</td>
#       <td id="T_a9d2d_row0_col1" class="data row0 col1" >Eventually King was released from jail.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9d2d_row1_col0" class="data row1 col0" >ANF-5</td>
#       <td id="T_a9d2d_row1_col1" class="data row1 col1" >The place inside Earth where energy is released first, starting an earthquake is called the focus of the earthquake.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9d2d_row2_col0" class="data row2 col0" >ANF-5</td>
#       <td id="T_a9d2d_row2_col1" class="data row2 col1" >Scientists classify earthquakes by estimating their strength, or amount of energy released.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9d2d_row3_col0" class="data row3 col0" >ANF-5</td>
#       <td id="T_a9d2d_row3_col1" class="data row3 col1" >Many gases released from factories and the burning of fossil fuels are toxic and pollute the air.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9d2d_row4_col0" class="data row4 col0" >ANF-5</td>
#       <td id="T_a9d2d_row4_col1" class="data row4 col1" >Then they release water vapor through their leaves into the atmosphere.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9d2d_row5_col0" class="data row5 col0" >ANF-5</td>
#       <td id="T_a9d2d_row5_col1" class="data row5 col1" >A star is a huge ball of burning gases that releases energy.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9d2d_row6_col0" class="data row6 col0" >ANF-6</td>
#       <td id="T_a9d2d_row6_col1" class="data row6 col1" >Energy is released as heat.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a9d2d_row7_col0" class="data row7 col0" >ANF-6</td>
#       <td id="T_a9d2d_row7_col1" class="data row7 col1" >When parts of Earth’s surface move or rub against each other, energy is released.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a9d2d_row8_col0" class="data row8 col0" >ANF-6</td>
#       <td id="T_a9d2d_row8_col1" class="data row8 col1" >The energy is released in all directions from that point of movement in Earth.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a9d2d_row9_col0" class="data row9 col0" >ANF-6</td>
#       <td id="T_a9d2d_row9_col1" class="data row9 col1" >This scanner releases sound waves and interprets the echoes that come back.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a9d2d_row10_col0" class="data row10 col0" >ESC-4</td>
#       <td id="T_a9d2d_row10_col1" class="data row10 col1" >“Ow!” he said, releasing her and grabbing the offended ear.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a9d2d_row11_col0" class="data row11 col0" >ESC-4</td>
#       <td id="T_a9d2d_row11_col1" class="data row11 col1" >However, in 1968, twenty- three years after the end of World War II, the secrets were released.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a9d2d_row12_col0" class="data row12 col0" >ESC-4</td>
#       <td id="T_a9d2d_row12_col1" class="data row12 col1" >In 1927, the first movie with sound was released.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a9d2d_row13_col0" class="data row13 col0" >ESC-4</td>
#       <td id="T_a9d2d_row13_col1" class="data row13 col1" >Now movie companies plan exciting blockbusters with lots of special effects to release each summer.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a9d2d_row14_col0" class="data row14 col0" >ESC-4</td>
#       <td id="T_a9d2d_row14_col1" class="data row14 col1" >Until then, few animation films were released each year.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a9d2d_row15_col0" class="data row15 col0" >ESC-5</td>
#       <td id="T_a9d2d_row15_col1" class="data row15 col1" >Their great surface area allows the fennec fox’s body heat to be released through its ears!</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a9d2d_row16_col0" class="data row16 col0" >ESC-5</td>
#       <td id="T_a9d2d_row16_col1" class="data row16 col1" >The nutria escaped or were released into the wild, where they thrived and multiplied.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a9d2d_row17_col0" class="data row17 col0" >ESC-5</td>
#       <td id="T_a9d2d_row17_col1" class="data row17 col1" >Master Filippus could not rally the scholars into any semblance of a group and released them for the day.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a9d2d_row18_col0" class="data row18 col0" >ESC-6</td>
#       <td id="T_a9d2d_row18_col1" class="data row18 col1" >Others add that the Persians released an army of cats onto the battlefield.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a9d2d_row19_col0" class="data row19 col0" >PTF4.2</td>
#       <td id="T_a9d2d_row19_col1" class="data row19 col1" >“But only catch-and-release fishing—you’d put the live fish back in the water,” Cristina said.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a9d2d_row20_col0" class="data row20 col0" >PTF4.2</td>
#       <td id="T_a9d2d_row20_col1" class="data row20 col1" >She released the tight coil of line that she was holding.</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a9

# %%
srcode_sentence()
# Out:
# |enter the UPOS:LEMMA ->  VERB: release
# |If you want to see only sentences : Enter 1
# |If you want to see story codes only : Enter 2
# |If you want to see both sentences and story codes : Enter 33
#
#
# < VERB:release >  appeared in 21 stories.
# ALPZ5-U1-S06, ANF5-U1-S03, ANF5-U1-S04, ANF5-U1-S05
# ANF5-U1-S09, ANF6-U1-S01, ANF6-U1-S07, ANF6-U1-S09
# ESC4-U1-S11, ESC4-U1-S14, ESC4-U1-S18, ESC5-U1-S03
# ESC5-U1-S05, ESC5-U1-S11, ESC6-U1-S05, PTF4.2-U2-S06
# ERK3-U1-S34, ERK3-U1-S35, ERK3-U1-S38, ERK3-U1-S39
# ERK3-U1-S12
#
# < VERB:release >  appeared in 28 sentences.
# <style type="text/css">
# #T_6107d_row0_col0, #T_6107d_row0_col1, #T_6107d_row1_col0, #T_6107d_row1_col1, #T_6107d_row2_col0, #T_6107d_row2_col1, #T_6107d_row3_col0, #T_6107d_row3_col1, #T_6107d_row4_col0, #T_6107d_row4_col1, #T_6107d_row5_col0, #T_6107d_row5_col1, #T_6107d_row6_col0, #T_6107d_row6_col1, #T_6107d_row7_col0, #T_6107d_row7_col1, #T_6107d_row8_col0, #T_6107d_row8_col1, #T_6107d_row9_col0, #T_6107d_row9_col1, #T_6107d_row10_col0, #T_6107d_row10_col1, #T_6107d_row11_col0, #T_6107d_row11_col1, #T_6107d_row12_col0, #T_6107d_row12_col1, #T_6107d_row13_col0, #T_6107d_row13_col1, #T_6107d_row14_col0, #T_6107d_row14_col1, #T_6107d_row15_col0, #T_6107d_row15_col1, #T_6107d_row16_col0, #T_6107d_row16_col1, #T_6107d_row17_col0, #T_6107d_row17_col1, #T_6107d_row18_col0, #T_6107d_row18_col1, #T_6107d_row19_col0, #T_6107d_row19_col1, #T_6107d_row20_col0, #T_6107d_row20_col1, #T_6107d_row21_col0, #T_6107d_row21_col1, #T_6107d_row22_col0, #T_6107d_row22_col1, #T_6107d_row23_col0, #T_6107d_row23_col1, #T_6107d_row24_col0, #T_6107d_row24_col1, #T_6107d_row25_col0, #T_6107d_row25_col1, #T_6107d_row26_col0, #T_6107d_row26_col1, #T_6107d_row27_col0, #T_6107d_row27_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_6107d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6107d_level0_col0" class="col_heading level0 col0" >SR Code</th>
#       <th id="T_6107d_level0_col1" class="col_heading level0 col1" >Sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6107d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6107d_row0_col0" class="data row0 col0" >ALPZ5-U1-S06</td>
#       <td id="T_6107d_row0_col1" class="data row0 col1" >Eventually King was released from jail.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6107d_row1_col0" class="data row1 col0" >ANF5-U1-S03</td>
#       <td id="T_6107d_row1_col1" class="data row1 col1" >The place inside Earth where energy is released first, starting an earthquake is called the focus of the earthquake.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6107d_row2_col0" class="data row2 col0" >ANF5-U1-S03</td>
#       <td id="T_6107d_row2_col1" class="data row2 col1" >Scientists classify earthquakes by estimating their strength, or amount of energy released.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6107d_row3_col0" class="data row3 col0" >ANF5-U1-S04</td>
#       <td id="T_6107d_row3_col1" class="data row3 col1" >Many gases released from factories and the burning of fossil fuels are toxic and pollute the air.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6107d_row4_col0" class="data row4 col0" >ANF5-U1-S05</td>
#       <td id="T_6107d_row4_col1" class="data row4 col1" >Then they release water vapor through their leaves into the atmosphere.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6107d_row5_col0" class="data row5 col0" >ANF5-U1-S09</td>
#       <td id="T_6107d_row5_col1" class="data row5 col1" >A star is a huge ball of burning gases that releases energy.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6107d_row6_col0" class="data row6 col0" >ANF6-U1-S01</td>
#       <td id="T_6107d_row6_col1" class="data row6 col1" >Energy is released as heat.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6107d_row7_col0" class="data row7 col0" >ANF6-U1-S07</td>
#       <td id="T_6107d_row7_col1" class="data row7 col1" >When parts of Earth’s surface move or rub against each other, energy is released.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6107d_row8_col0" class="data row8 col0" >ANF6-U1-S07</td>
#       <td id="T_6107d_row8_col1" class="data row8 col1" >The energy is released in all directions from that point of movement in Earth.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6107d_row9_col0" class="data row9 col0" >ANF6-U1-S09</td>
#       <td id="T_6107d_row9_col1" class="data row9 col1" >This scanner releases sound waves and interprets the echoes that come back.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6107d_row10_col0" class="data row10 col0" >ESC4-U1-S11</td>
#       <td id="T_6107d_row10_col1" class="data row10 col1" >“Ow!” he said, releasing her and grabbing the offended ear.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6107d_row11_col0" class="data row11 col0" >ESC4-U1-S14</td>
#       <td id="T_6107d_row11_col1" class="data row11 col1" >However, in 1968, twenty- three years after the end of World War II, the secrets were released.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6107d_row12_col0" class="data row12 col0" >ESC4-U1-S18</td>
#       <td id="T_6107d_row12_col1" class="data row12 col1" >In 1927, the first movie with sound was released.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6107d_row13_col0" class="data row13 col0" >ESC4-U1-S18</td>
#       <td id="T_6107d_row13_col1" class="data row13 col1" >Now movie companies plan exciting blockbusters with lots of special effects to release each summer.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6107d_row14_col0" class="data row14 col0" >ESC4-U1-S18</td>
#       <td id="T_6107d_row14_col1" class="data row14 col1" >Until then, few animation films were released each year.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6107d_row15_col0" class="data row15 col0" >ESC5-U1-S03</td>
#       <td id="T_6107d_row15_col1" class="data row15 col1" >Their great surface area allows the fennec fox’s body heat to be released through its ears!</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6107d_row16_col0" class="data row16 col0" >ESC5-U1-S05</td>
#       <td id="T_6107d_row16_col1" class="data row16 col1" >The nutria escaped or were released into the wild, where they thrived and multiplied.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6107d_row17_col0" class="data row17 col0" >ESC5-U1-S11</td>
#       <td id="T_6107d_row17_col1" class="data row17 col1" >Master Filippus could not rally the scholars into any semblance of a group and released them for the day.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6107d_row18_col0" class="data row18 col0" >ESC6-U1-S05</td>
#       <td id="T_6107d_row18_col1" class="data row18 col1" >Others add that the Persians released an army of cats onto the battlefield.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6107d_row19_col0" class="data row19 col0" >PTF4.2-U2-S06</td>
#       <td id="T_6107d_row19_col1" class="data row19 col1" >“But only catch-and-release fishing—you’d put the live fish back in the water,” Cristina said.</td>
#     </tr>
#     <tr>
#       <th id="T_6107d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6107d_row20_col0" class="data row20 col0" >PTF4.2-U2-S06</td>
#       <td id="T_6107d_row20_col1" class="data row20 col1" >She released the tight coil of line that she was h
